# %%
from doc_debugger import render_ai_parse_output_interactive

# %%
dbutils.widgets.text("catalog", "")
dbutils.widgets.text("schema", "")
catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")

# %%
parsed = [row.parsed for row in spark.table(f"{catalog}.{schema}.parsed").collect()]
render_ai_parse_output_interactive(parsed)
